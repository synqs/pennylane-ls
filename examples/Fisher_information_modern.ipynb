# %% [markdown]
# # Example Notebook for Number Squeezing

# %%
import pennylane as qml
import numpy as np
import matplotlib.pyplot as plt

import strawberryfields as sf
from strawberryfields import ops

from scipy.optimize import curve_fit

import pandas as pd

# %config InlineBackend.figure_format='retina'

# %% [markdown]
# We first want to look at what we are trying to reproduce with pennylane. The graph below is from a [paper](https://arxiv.org/abs/1507.03782) by Helmut Strobel. In this paper the collective spin of a Bose-Einstein-Condensate is used to observe nonlinearity in spin squeezing. This notebook aims to simulate the experimental results using pennylane.

# %%
data_strobel_15 = pd.read_csv('Data/Strobel_Data_15ms.csv', names = ['dB', "alpha"])
data_strobel_25 = pd.read_csv('Data/Strobel_Data_25ms.csv', names = ['dB', "alpha"])

plt.figure(dpi=96)
plt.title("Number Squeezing")
plt.plot(data_strobel_15.dB, data_strobel_15.alpha, 'o', label="15ms", markersize=4)
plt.plot(data_strobel_25.dB, data_strobel_25.alpha, 'o', label="25ms", markersize=4)
plt.axhline(y=0, color='g', linestyle='--')
plt.ylabel(r'Number Squeezing in $dB$')
plt.xlabel(r'tomography angle $\alpha$')
_ = plt.legend()

# %% [markdown]
# This number squeezing is achieved by performing the following Bloch-sphere rotations.
#
# We prepare the collective spin such that the Bloch-sphere-vector points to one of the poles.
#
# #### First step
# As a first step the vector is rotated onto the equator.
# <center><img width="200" height="300" src="Bloch_spheres/1.png"><\center>

# %% [markdown]
# #### Second step
# Then the state is being squeezed, such that it starts to wrap around the Bloch-sphere.
#
# <center><img width="200" height="300" src="Bloch_spheres/2.png"><\center>

# %% [markdown]
# #### Third step
# In the last step we rotate the state around the $X$-axis. This rotation corresponds to the angle $\alpha$ in this notebook.
#
# <center>
# <img width="300" height="400" src="Bloch_spheres/alpha.png">
# <\center>

# %% [markdown]
# ## experimental parameters
#
# the experimental parameters are

# %%
Nat = 200; # 380
omegax = 2*np.pi*20;
t1 = 15e-3;
t2 = 25e-3;
Lambda = 1.5;#1.5

chi = Lambda*omegax/Nat;

Ntrott = 12;

# %% [markdown]
# each atom has two internal states, so we have $N_{at}+1$ states available. It can be mapped onto a spin with dimension $2*L+1$, setting them equal tells us that $L = N_{at}/2$

# %% [markdown]
# # The approach with exact matrices.

# %%
from scipy.sparse.linalg import expm
from scipy.sparse import coo_matrix, csc_matrix, diags, identity

import qutip as q
from qutip import Qobj

# %%
l = Nat/2 # spin length

# let's put together spin matrices
dim_qudit = 2*l+1
qudit_range = np.arange(l, -(l+1),-1)

Id  =  csc_matrix(identity(dim_qudit))
Lx  =  csc_matrix(1/2*diags([np.sqrt([(l-m+1)*(l+m) for m in qudit_range[:-1]]), np.sqrt([(l+m+1)*(l-m) for m in qudit_range[1:]]) ], [-1, 1]))
Ly  =  csc_matrix(1/(2*1j)*diags([np.sqrt([(l-m+1)*(l+m) for m in qudit_range[:-1]]), -1 *np.sqrt([(l+m+1)*(l-m) for m in qudit_range[1:]]) ], [-1, 1]))
Lz  =  csc_matrix(diags([qudit_range], [0]))
Lz2 = Lz.multiply(Lz)
Lx2 = Lx.multiply(Lx)

# %%
Ham = chi*Lz2-omegax*Lx

# %% [markdown]
# some helpful functions

# %%
def Ry(psi, theta):
    Uy = expm(-1j*theta*Ly).toarray()
    psi = np.dot(Uy,psi)
    return psi

def Rx(psi, theta):
    Ux = expm(-1j*theta*Lx).toarray()
    psi = np.dot(Ux,psi)
    return psi

def number_squeezing_factor_to_db(var_CSS, var):
    return 10*np.log10(var/var_CSS)

def Hamiltonian(psi, chi, omega, t):
    return psi@expm(-1j*t*(chi*Lz2 - omega*Lx))

def Helmut_steps(chi, omega, alpha, t, minus=False):
    
    psis = []
    
    psi = 1j*np.zeros(Nat+1)
    psi[0] = 1+1j*0   
    psis.append(psi)
    
    psi = Ry(psi, np.pi/2)  
    psis.append(psi)
    
    psi = Hamiltonian(psi, chi, omega, t/2)   
    psis.append(psi)  
    
    #psi = Rx(psi, np.pi)  
    #psis.append(psi)
    
    psi = Hamiltonian(psi, chi, omega, t/2)   
    psis.append(psi)
    
    if minus:
        psi = Rx(psi, -alpha)   
        psis.append(psi)
    else:
        psi = Rx(psi, alpha)   
        psis.append(psi)
    
    return psis

# %% [markdown]
# now apply the steps.

# %%
alphas = np.linspace(0, np.pi, 25)
variances_1 = np.zeros(len(alphas))
variances_2 = np.zeros(len(alphas))


for i in range(len(alphas)):
    if i%10==0:
        print("step", i)
    # Calculate the resulting states after each rotation
    resulting_states_1 = Helmut_steps(chi, omegax, alphas[i], t1)
    
    # Turn last state into Qobject
    Qobj_state_1 = Qobj(resulting_states_1[-1])
    
    # Calculate and save variances
    var_1 = q.variance(q.spin_Jz(l), Qobj_state_1)
    variances_1[i] = var_1
    
    # Calculate the resulting states after each rotation
    resulting_states_2 = Helmut_steps(chi, omegax, alphas[i], t2)
    
    # Turn last state into Qobject
    Qobj_state_2 = Qobj(resulting_states_2[-1])
    
    # Calculate and save variances
    var_2 = q.variance(q.spin_Jz(l), Qobj_state_2)
    variances_2[i] = var_2
# Out:
# step 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/43/kdr803yn1rn0wmfhldfxhx_40000gn/T/ipykernel_86917/797509322.py in <module>
#      18
#      19     # Calculate the resulting states after each rotation
# ---> 20     resulting_states_2 = Helmut_steps(chi, omegax, alphas[i], t2)
#      21
#      22     # Turn last state into Qobject
#
# /var/folders/43/kdr803yn1rn0wmfhldfxhx_40000gn/T/ipykernel_86917/2180409903.py in Helmut_steps(chi, omega, alpha, t, minus)
#      32     #psis.append(psi)
#      33
# ---> 34     psi = Hamiltonian(psi, chi, omega, t/2)
#      35     psis.append(psi)
#      36
#
# /var/folders/43/kdr803yn1rn0wmfhldfxhx_40000gn/T/ipykernel_86917/2180409903.py in Hamiltonian(psi, chi, omega, t)
#      13
#      14 def Hamiltonian(psi, chi, omega, t):
# ---> 15     return psi@expm(-1j*t*(chi*Lz2 - omega*Lx))
#      16
#      17 def Helmut_steps(chi, omega, alpha, t, minus=False):
#
# ~/opt/miniconda3/envs/pennylane/lib/python3.9/site-packages/scipy/sparse/linalg/matfuncs.py in expm(A)
#     589             [  0.        ,   0.        ,  20.08553692]])
#     590     """
# --> 591     return _expm(A, use_exact_onenorm='auto')
#     592
#     593
#
# ~/opt/miniconda3/envs/pennylane/lib/python3.9/site-packages/scipy/sparse/linalg/matfuncs.py in _expm(A, use_exact_onenorm)
#     671     s = s + _ell(2**-s * h.A, 13)
#     672     U, V = h.pade13_scaled(s)
# --> 673     X = _solve_P_Q(U, V, structure=structure)
#     674     if structure == UPPER_TRIANGULAR:
#     675         # Invoke Code Fragment 2.1.
#
# ~/opt/miniconda3/envs/pennylane/lib/python3.9/site-packages/scipy/sparse/linalg/matfuncs.py in _solve_P_Q(U, V, structure)
#     705     Q = -U + V
#     706     if isspmatrix(U) or is_pydata_spmatrix(U):
# --> 707         return spsolve(Q, P)
#     708     elif structure is None:
#     709         return solve(Q, P)
#
# ~/opt/miniconda3/envs/pennylane/lib/python3.9/site-packages/scipy/sparse/linalg/dsolve/linsolve.py in spsolve(A, b, permc_spec, use_umfpack)
#     223             col_segs = []
#     224             for j in range(b.shape[1]):
# --> 225                 bj = np.asarray(b[:, j].todense()).ravel()
#     226                 xj = Afactsolve(bj)
#     227                 w = np.flatnonzero(xj)
#
# ~/opt/miniconda3/envs/pennylane/lib/python3.9/site-packages/scipy/sparse/_index.py in __getitem__(self, key)
#      43         elif isinstance(row, slice):
#      44             if isinstance(col, INT_TYPES):
# ---> 45                 return self._get_sliceXint(row, col)
#      46             elif isinstance(col, slice):
#      47                 if row == slice(None) and row == col:
#
# ~/opt/miniconda3/envs/pennylane/lib/python3.9/site-packages/scipy/sparse/csc.py in _get_sliceXint(self, row, col)
#     214     def _get_sliceXint(self, row, col):
#     215         if row.step in (1, None):
# --> 216             return self._get_submatrix(major=col, minor=row, copy=True)
#     217         return self._get_submatrix(major=col)._minor_slice(row)
#     218
#
# ~/opt/miniconda3/envs/pennylane/lib/python3.9/site-packages/scipy/sparse/compressed.py in _get_submatrix(self, major, minor, copy)
#     793
#     794         shape = self._swap((i1 - i0, j1 - j0))
# --> 795         return self.__class__((data, indices, indptr), shape=shape,
#     796                               dtype=self.dtype, copy=False)
#     797
#
# ~/opt/miniconda3/envs/pennylane/lib/python3.9/site-packages/scipy/sparse/compressed.py in __init__(self, arg1, shape, dtype, copy)
#     104             self.data = self.data.astype(dtype, copy=False)
#     105
# --> 106         self.check_format(full_check=False)
#     107
#     108     def getnnz(self, axis=None):
#
# KeyboardInterrupt:

# %% [markdown]
# compare theory and experiment

# %%
f, ax = plt.subplots()
ax.set_title("Number Squeezing")
ax.plot(data_strobel_15.dB, data_strobel_15.alpha, 'ro', label="15ms", markersize=4)
plt.plot(np.rad2deg(alphas), number_squeezing_factor_to_db(l/2, variances_1),'r-', label=fr"$t_1={t1}s$")
ax.plot(data_strobel_25.dB, data_strobel_25.alpha, 'go', label="25ms", markersize=4)
plt.plot(np.rad2deg(alphas), number_squeezing_factor_to_db(l/2, variances_2),'g-', label=fr"$t_2={t2}s$")
ax.axhline(y=0, color='g', linestyle='--')
ax.set_ylabel(r'Number Squeezing in $dB$')
ax.set_xlabel(r'tomography angle $\alpha$')
ax.legend()

# %% [markdown]
# # the pennylane approach

# %%
import pennylane as qml
import numpy as np
import sys

# %%
import sys
sys.path.append('../')

# %%
from pennylane_ls import *

# %%
from heroku_credentials import username, password

# %%
testDevice = SingleQuditDevice(shots = 8, username = username, password = password)

# %%
testDevice.operations
# Out:
# {'load', 'rLx', 'rLz', 'rLz2'}

# %% [markdown]
# ### For the single qudit simulator

# %%
@qml.qnode(testDevice)
def quantum_circuit(Nat = 10, theta = 0, kappa = 0, alpha=0):
    '''
    The circuit that simulates the experiments.
    
    theta ... angle of the Lx term in the Hamiltonian evolution
    kappa ... angle of the Lz^2 term in the Hamiltonian evolution
    apla ... angle of rotation
    '''
    # load atoms
    load(Nat,wires=0)
    
    # rotate onto x
    rLx(np.pi/2,wires=0)
    rLz(np.pi/2,wires=0)
    
    # evolution under the Hamiltonian
    rLx(theta, wires=0)
    rLz2(kappa, wires=0)

    # and the final rotation to test the variance
    rLx(alpha, wires=0)
    return qml.var(Lz(0))

# %%
quantum_circuit(10)
# Out:
# tensor(1.484375, requires_grad=True)

# %%
theta1
kappa1
# Out:
# 0.2827433388230814

# %%
Nat = 10;
omegax = 2*np.pi*20;
t1 = 15e-3;
t2 = 25e-3;
Lambda = 1.5;#1.5

chi = Lambda*omegax/Nat;

Ntrott = 12;

# %%
alphas = np.linspace(0, np.pi, 25)
variances_1 = np.zeros(len(alphas))

theta1 = -omegax*t1/2
kappa1 = chi*t1

for i in range(len(alphas)):
    if i%10==0:
        print("step", i)
    # Calculate the resulting states after each rotation
    variances_1[i] = quantum_circuit(Nat, theta1, kappa1, alphas[i])
# Out:
# step 0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Documents/GitHub/pennylane_ls/examples/../pennylane_ls/SingleQuditDevice.py in var(self, observable, wires, par)
#      83         try:
# ---> 84             shots = self.sample(observable, wires, par)
#      85             return shots.var()
#
# ~/Documents/GitHub/pennylane_ls/examples/../pennylane_ls/SingleQuditDevice.py in sample(self, observable, wires, par)
#     112             results_dict = json.loads(result_response.text)
# --> 113             shots = results_dict["results"][0]['data']['memory']
#     114             shots = np.array([int(shot) for shot in shots])
#
# KeyError: 'results'
#
# During handling of the above exception, another exception occurred:
#
# NotImplementedError                       Traceback (most recent call last)
# /var/folders/43/kdr803yn1rn0wmfhldfxhx_40000gn/T/ipykernel_86917/2892860593.py in <module>
#       9         print("step", i)
#      10     # Calculate the resulting states after each rotation
# ---> 11     variances_1[i] = quantum_circuit(Nat, theta1, kappa1, alphas[i])
#
# ~/opt/miniconda3/envs/pennylane/lib/python3.9/site-packages/pennylane/qnode.py in __call__(self, *args, **kwargs)
#     596
#     597         # execute the tape
# --> 598         res = self.qtape.execute(device=self.device)
#     599
#     600         # if shots was changed
#
# ~/opt/miniconda3/envs/pennylane/lib/python3.9/site-packages/pennylane/tape/tape.py in execute(self, device, params)
#    1321             params = self.get_parameters()
#    1322
# -> 1323         return self._execute(params, device=device)
#    1324
#    1325     def execute_device(self, params, device):
#
# ~/opt/miniconda3/envs/pennylane/lib/python3.9/site-packages/autograd/tracer.py in f_wrapped(*args, **kwargs)
#      46             return new_box(ans, trace, node)
#      47         else:
# ---> 48             return f_raw(*args, **kwargs)
#      49     f_wrapped.fun = f_raw
#      50     f_wrapped._is_autograd_primitive = True
#
# ~/opt/miniconda3/envs/pennylane/lib/python3.9/site-packages/pennylane/interfaces/autograd.py in _execute(self, params, device)
#     163         # evaluate the tape
#     164         self.set_parameters(self._all_params_unwrapped, trainable_only=False)
# --> 165         res = self.execute_device(params, device=device)
#     166         self.set_parameters(self._all_parameter_values, trainable_only=False)
#     167
#
# ~/opt/miniconda3/envs/pennylane/lib/python3.9/site-packages/pennylane/tape/tape.py in execute_device(self, params, device)
#    1354             res = device.execute(self)
#    1355         else:
# -> 1356             res = device.execute(self.operations, self.observables, {})
#    1357
#    1358         # Update output dim if incorrect.
#
# ~/opt/miniconda3/envs/pennylane/lib/python3.9/site-packages/pennylane/_device.py in execute(self, queue, observables, parameters, **kwargs)
#     428
#     429                 elif obs.return_type is Variance:
# --> 430                     results.append(self.var(obs.name, wires, obs.parameters))
#     431
#     432                 elif obs.return_type is Sample:
#
# ~/Documents/GitHub/pennylane_ls/examples/../pennylane_ls/SingleQuditDevice.py in var(self, observable, wires, par)
#      85             return shots.var()
#      86         except:
# ---> 87             raise NotImplementedError()
#      88
#      89     def sample(self, observable, wires, par):
#
# NotImplementedError:

# %%
quantum_circuit(Nat, theta1, kappa1, alphas[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Documents/GitHub/pennylane_ls/examples/../pennylane_ls/SingleQuditDevice.py in var(self, observable, wires, par)
#      83         try:
# ---> 84             shots = self.sample(observable, wires, par)
#      85             return shots.var()
#
# ~/Documents/GitHub/pennylane_ls/examples/../pennylane_ls/SingleQuditDevice.py in sample(self, observable, wires, par)
#     112             results_dict = json.loads(result_response.text)
# --> 113             shots = results_dict["results"][0]['data']['memory']
#     114             shots = np.array([int(shot) for shot in shots])
#
# KeyError: 'results'
#
# During handling of the above exception, another exception occurred:
#
# NotImplementedError                       Traceback (most recent call last)
# /var/folders/43/kdr803yn1rn0wmfhldfxhx_40000gn/T/ipykernel_86917/2618709404.py in <module>
# ----> 1 quantum_circuit(Nat, theta1, kappa1, alphas[0])
#
# ~/opt/miniconda3/envs/pennylane/lib/python3.9/site-packages/pennylane/qnode.py in __call__(self, *args, **kwargs)
#     596
#     597         # execute the tape
# --> 598         res = self.qtape.execute(device=self.device)
#     599
#     600         # if shots was changed
#
# ~/opt/miniconda3/envs/pennylane/lib/python3.9/site-packages/pennylane/tape/tape.py in execute(self, device, params)
#    1321             params = self.get_parameters()
#    1322
# -> 1323         return self._execute(params, device=device)
#    1324
#    1325     def execute_device(self, params, device):
#
# ~/opt/miniconda3/envs/pennylane/lib/python3.9/site-packages/autograd/tracer.py in f_wrapped(*args, **kwargs)
#      46             return new_box(ans, trace, node)
#      47         else:
# ---> 48             return f_raw(*args, **kwargs)
#      49     f_wrapped.fun = f_raw
#      50     f_wrapped._is_autograd_primitive = True
#
# ~/opt/miniconda3/envs/pennylane/lib/python3.9/site-packages/pennylane/interfaces/autograd.py in _execute(self, params, device)
#     163         # evaluate the tape
#     164         self.set_parameters(self._all_params_unwrapped, trainable_only=False)
# --> 165         res = self.execute_device(params, device=device)
#     166         self.set_parameters(self._all_parameter_values, trainable_only=False)
#     167
#
# ~/opt/miniconda3/envs/pennylane/lib/python3.9/site-packages/pennylane/tape/tape.py in execute_device(self, params, device)
#    1354             res = device.execute(self)
#    1355         else:
# -> 1356             res = device.execute(self.operations, self.observables, {})
#    1357
#    1358         # Update output dim if incorrect.
#
# ~/opt/miniconda3/envs/pennylane/lib/python3.9/site-packages/pennylane/_device.py in execute(self, queue, observables, parameters, **kwargs)
#     428
#     429                 elif obs.return_type is Variance:
# --> 430                     results.append(self.var(obs.name, wires, obs.parameters))
#     431
#     432                 elif obs.return_type is Sample:
#
# ~/Documents/GitHub/pennylane_ls/examples/../pennylane_ls/SingleQuditDevice.py in var(self, observable, wires, par)
#      85             return shots.var()
#      86         except:
# ---> 87             raise NotImplementedError()
#      88
#      89     def sample(self, observable, wires, par):
#
# NotImplementedError:
